# %%
import pandas as pd
import numpy as np
from pathlib import Path
import sys
from pathlib import Path
import os

# sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

# %%
# src_path = Path.cwd().parent 
# sys.path.append(str(src_path))

# %%
df=pd.read_csv('../data/data.csv')

# %%
from sklearn.model_selection import train_test_split

# Features and label
X = df.drop('Bankrupt?', axis=1)
y = df['Bankrupt?']


# Split the data into training and testing sets+
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y,random_state=42)

# %%
test=df.sample(100)

# %%
test.to_csv('../data/test.csv')

# %%
import sys
import os
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))  # Adjust '..' as needed
if project_root not in sys.path:
    sys.path.append(project_root)
print(sys.path)
# Out:
# ['/usr/lib/python310.zip', '/usr/lib/python3.10', '/usr/lib/python3.10/lib-dynload', '', '/home/gm/.local/lib/python3.10/site-packages', '/home/gm/Desktop/visa_pred/End-to-End-US-Visa-Approval-Prediction', '/usr/local/lib/python3.10/dist-packages', '/usr/lib/python3/dist-packages', '/home/gm/Desktop/Financial_model_Taiwan/Project']

# %%
import os
print(os.listdir(project_root))
# Out:
# ['data', 'requirements.txt', 'tests', 'README.md', '.pytest_cache', 'Dockerfile', 'models', 'File_structure.py', 'config', 'src', '.gitignore', 'notebooks']

# %%
print(os.listdir(os.path.join(project_root, 'src')))
# Out:
# ['model_evaluation.py', 'Custom_Transformers.py', '__init__.py', 'utils.py', 'Model_arch.py', 'Data_Resampling.py', '__pycache__', 'model_training.py', 'data_preprocessing.py']

# %%
# import src

import src
# src.Data_Resampling

# %%
src
# Out:
# <module 'src' from '/home/gm/Desktop/visa_pred/End-to-End-US-Visa-Approval-Prediction/src/__init__.py'>

# %%
import src.data_preprocessing
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 import src.data_preprocessing
#
# ModuleNotFoundError: No module named 'src.data_preprocessing'

# %%
for module in ['model_evaluation', 'Custom_Transformers', 'utils', 'Model_arch', 'Data_Resampling', 'model_training', 'data_preprocessing']:
    try:
        exec(f"from src import {module}")
        print(f"Successfully imported {module}")
    except Exception as e:
        print(f"Error importing {module}: {e}")
# Out:
# Error importing model_evaluation: cannot import name 'model_evaluation' from 'src' (/home/gm/Desktop/visa_pred/End-to-End-US-Visa-Approval-Prediction/src/__init__.py)
# Error importing Custom_Transformers: cannot import name 'Custom_Transformers' from 'src' (/home/gm/Desktop/visa_pred/End-to-End-US-Visa-Approval-Prediction/src/__init__.py)
# Error importing utils: cannot import name 'utils' from 'src' (/home/gm/Desktop/visa_pred/End-to-End-US-Visa-Approval-Prediction/src/__init__.py)
# Error importing Model_arch: cannot import name 'Model_arch' from 'src' (/home/gm/Desktop/visa_pred/End-to-End-US-Visa-Approval-Prediction/src/__init__.py)
# Error importing Data_Resampling: cannot import name 'Data_Resampling' from 'src' (/home/gm/Desktop/visa_pred/End-to-End-US-Visa-Approval-Prediction/src/__init__.py)
# Error importing model_training: cannot import name 'model_training' from 'src' (/home/gm/Desktop/visa_pred/End-to-End-US-Visa-Approval-Prediction/src/__init__.py)
# ...

# %%
import src.data_preprocessing
print(src.data_preprocessing)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 import src.data_preprocessing
#       2 print(src.data_preprocessing)
#
# ModuleNotFoundError: No module named 'src.data_preprocessing'

# %%
# %load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
preprocess=PreprocessingPipeline()
pipeline=preprocess.preprocessing()

# %%
pipeline
# Out:
# Pipeline(steps=[('outlier_capper', OutlierCapper()),
#                 ('constant_filter', DataFrameVarianceThreshold()),
#                 ('log_transform', DF_log_transform()),
#                 ('scaler', DataFrameScaler()),
#                 ('feature_selector', FeatureSelector())])

# %%
# %autoreload 2

# %%
pipeline.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('outlier_capper', OutlierCapper()),
#                 ('constant_filter', DataFrameVarianceThreshold()),
#                 ('log_transform', DF_log_transform()),
#                 ('scaler', DataFrameScaler()),
#                 ('feature_selector', FeatureSelector())])

# %%
X_train
# Out:
#        ROA(C) before interest and depreciation before interest  \
# 318                                            0.493784
# 5796                                           0.534393
# 4454                                           0.526398
# 2225                                           0.469702
# 3249                                           0.391557
# ...                                                 ...
# 4688                                           0.550090
# 1078                                           0.481597
# 6687                                           0.622288
# 2623                                           0.586847
# 665                                            0.500951
#
#        ROA(A) before interest and % after tax  \
# 318                                  0.550153
# 5796                                 0.590765
# 4454                                 0.586895
# 2225                                 0.536851
# 3249                                 0.443197
# ...

# %%
transformed=pipeline.transform(X_train)

# %%
transformed
# Out:
#        ROA(A) before interest and % after tax   Operating Profit Rate  \
# 318                                 -0.117628               -0.111312
# 5796                                 0.558854                0.085616
# 4454                                 0.495133                0.452993
# 2225                                -0.343045               -0.173250
# 3249                                -1.987700               -6.373233
# ...                                       ...                     ...
# 4688                                 0.113159                0.188843
# 1078                                -0.491921                0.078205
# 6687                                 2.414220               -0.562357
# 2623                                 1.390777                0.271424
# 665                                  0.158709                0.102027
#
#        Pre-tax net Interest Rate   Continuous interest rate (after tax)  \
# ...

# %%
y_train
# Out:
# 318     0
# 5796    0
# 4454    0
# 2225    0
# 3249    0
#        ..
# 4688    0
# 1078    0
# 6687    0
# 2623    0
# 665     0
# Name: Bankrupt?, Length: 5455, dtype: int64

# %%
from Data_Resampling import Resample
